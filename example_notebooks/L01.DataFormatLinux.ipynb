# %% [markdown]
# ## What you need to do before this tutorial?
#
# (1) Watch this Youtube video:
#
# 60 Linux Commands you NEED to know (in 10 minutes)
#
# https://www.youtube.com/watch?v=gd7BXuUQ91w
#
# (2) Read this cheat sheet
#
# Cheat Sheet for Linux Command
#
# https://www.guru99.com/linux-commands-cheat-sheet.html

# %% [markdown]
# **BIO/CSE/MBI 466/566  Tutorial 01  Linux Commands**
#
# **1. Introduction**
#
# Linux Operating System (OS) is one of three popular OS systems: Windows, Mac OS and Unix. Linux is a personalized version of Unix.  Linux is the major OS for bioinformatics.
#
# In this tutorial we will learn Linux and its basic commands.
#
# For this course, you will use Linux in two platform:
# * (A)   Colab in your University Gmail accounts
# * (B)   Miami University RedHawk cluster (You will need it for your final project)
# * (C)   Liang Lab 10.34.229.118 Web Server (You will need it for your final project)
#
# The difference in terms of Linux commands is that for (A), you need to add "!" symbol before any of your Linux commands whereas you do not need to add "!" for (B) and (C).

# %% [markdown]
# **2. Basic Linux Commands and Shell**
#
# * Learn the directory and file structure in Linux.
# * Get yourself familiar with basic Linux commands (pwd, ls, cd, cat, echo).
# * Understand the concepts of Shell and bash shell.

# %%
! pwd       # Check your current folder
# Out:
# /content

# %%
! ls -al    # List the content of your current folder
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Jul  7 17:00 .
# drwxr-xr-x 1 root root 4096 Jul  7 16:33 ..
# drwxr-xr-x 4 root root 4096 Jul  1 21:04 .config
# drwxr-xr-x 2 root root 4096 Jul  7 17:00 genome
# drwxr-xr-x 1 root root 4096 Jul  1 21:04 sample_data

# %%
! ls /      # List the content of your root folder for you cloud-based linux machine
           # Make sure you know how to differentiate a subfolder and a file
# Out:
# bin			    kaggle		      opt		 sys
# boot			    lib			      proc		 tmp
# content			    lib32		      python-apt	 tools
# cuda-keyring_1.1-1_all.deb  lib64		      python-apt.tar.xz  usr
# datalab			    libx32		      root		 var
# dev			    media		      run
# etc			    mnt			      sbin
# home			    NGC-DL-CONTAINER-LICENSE  srv

# %%
! ls /etc/  # List the content of the folder of "etc"
# Out:
# adduser.conf		       java-11-openjdk	profile
# alternatives		       jupyter		profile.d
# apparmor.d		       kernel		pulse
# apt			       ld.so.cache	python3
# bash.bashrc		       ld.so.conf	python3.10
# bash_completion.d	       ld.so.conf.d	python3.11
# bindresvport.blacklist	       legal		R
# binfmt.d		       libaudit.conf	rc0.d
# ca-certificates		       libibverbs.d	rc1.d
# ca-certificates.conf	       libnl-3		rc2.d
# ca-certificates.conf.dpkg-old  libpaper.d	rc3.d
# cloud			       locale.alias	rc4.d
# cron.d			       locale.gen	rc5.d
# cron.daily		       localtime	rc6.d
# cron.weekly		       logcheck		rcS.d
# cufile.json		       login.defs	requirements3.txt
# dbus-1			       logrotate.d	requirements.core.in
# dconf			       lsb-release	requirements.in
# debconf.conf		       machine-id	requirements.user.in
# debian_version		       magic		resolv.conf
# default			       magic.mime	rmt
# deluser.conf		       mailcap		security
# depmod.d		       mailcap.order	selinux
# ...

# %%
#####  You can use the command to check what OS runing for your Linux machine in cloud.

! cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.4 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.4 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %% [markdown]
# ####  **Task01**:  Use the graphic interface to locate this file named "os-release" and open it. (Hint: click the file icon on the left panel and navigate the directory and file systems.

# %%
##### Create a folder named "genome", which needs to be within /content/ folder
! mkdir /content/genome

# %%
! cd /content/genome

# %%
! pwd
# Out:
# /content

# %%
! cd /content/genome && pwd
# Out:
# /content/genome

# %%
! pwd
# Out:
# /content

# %% [markdown]
# ##### The above behavior sounds wired.  Why?
# ##### As we know, in Linux, a shell, which is a command-line interpreter, will take your commands and translates them into instructions that OS understand. In Colab (A), each time when "!" is used to issue a new command, a new, different shell will be used to interpreters and translates your command. Meanwhile, for (B) and (C), when you open a terminal, you start a shell, it will terminate until you close your terminal.

# %%
#####  How to check if Colab has the popular shell to interpreters and translates your commands?
! echo $SHELL
# Out:
# /bin/bash

# %% [markdown]
# ####  **Task02**:  Within the folder /content/genome, create a subfolder named "human".  Use the same shell to check the content of this newly created folder. What do you find?  What do they mean?

# %%
! mkdir /content/genome/human && ls -al /content/genome/human
# Out:
# total 8
# drwxr-xr-x 2 root root 4096 Jul  7 17:54 .
# drwxr-xr-x 3 root root 4096 Jul  7 17:54 ..

# %% [markdown]
# **3. Download human genomics data**
#
# * Human genome sequence data (https://ftp.ensembl.org/pub/release-114/fasta/homo_sapiens/dna/)
# * Human gene annotation GFF3 data (https://ftp.ensembl.org/pub/release-114/gff3/homo_sapiens/)
# * Human gene annotation GTF data (https://ftp.ensembl.org/pub/release-114/gtf/homo_sapiens/)
# * Human cDNA data (https://ftp.ensembl.org/pub/release-114/fasta/homo_sapiens/cdna/)
# * Human ncRNA data (https://ftp.ensembl.org/pub/release-114/fasta/homo_sapiens/ncrna/)
# * Learn other Linux commands (less, rm, cp, mv, chmod, head, tail)

# %%
! wget https://ftp.ensembl.org/pub/release-114/fasta/homo_sapiens/dna/Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz -P /content/genome/human
! wget https://ftp.ensembl.org/pub/release-114/gff3/homo_sapiens/Homo_sapiens.GRCh38.114.chromosome.1.gff3.gz -P /content/genome/human
# Out:
# --2025-07-07 19:52:55--  https://ftp.ensembl.org/pub/release-114/fasta/homo_sapiens/dna/Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69273468 (66M) [application/x-gzip]
# Saving to: ‘/content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz’
#
# Homo_sapiens.GRCh38 100%[===================>]  66.06M  31.8MB/s    in 2.1s
#
# 2025-07-07 19:52:58 (31.8 MB/s) - ‘/content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz’ saved [69273468/69273468]
#
# --2025-07-07 19:52:58--  https://ftp.ensembl.org/pub/release-114/gff3/homo_sapiens/Homo_sapiens.GRCh38.114.chromosome.1.gff3.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
! ls -al /content/genome/human
# Out:
# total 72744
# drwxr-xr-x 2 root root     4096 Jul  7 19:52 .
# drwxr-xr-x 3 root root     4096 Jul  7 19:52 ..
# -rw-r--r-- 1 root root  5203336 Feb 15 15:49 Homo_sapiens.GRCh38.114.chromosome.1.gff3.gz
# -rw-r--r-- 1 root root 69273468 Jan 30 20:44 Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz

# %%
! chmod a+rwx /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz
! chmod a+rwx /content/genome/human/Homo_sapiens.GRCh38.114.chromosome.1.gff3.gz
! ls -al /content/genome/human
# Out:
# total 72744
# drwxr-xr-x 2 root root     4096 Jul  7 19:52 .
# drwxr-xr-x 3 root root     4096 Jul  7 19:52 ..
# -rwxrwxrwx 1 root root  5203336 Feb 15 15:49 Homo_sapiens.GRCh38.114.chromosome.1.gff3.gz
# -rwxrwxrwx 1 root root 69273468 Jan 30 20:44 Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz

# %%
##### Unzip the downloaded files. The unzipped files are in the same folder as zipped files.
# !gunzip -k /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz
# !gunzip -k /content/genome/human/Homo_sapiens.GRCh38.114.chromosome.1.gff3.gz
# Out:
# gzip: /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa already exists; do you wish to overwrite (y or n)? ^C
# gzip: /content/genome/human/Homo_sapiens.GRCh38.114.chromosome.1.gff3 already exists; do you wish to overwrite (y or n)? ^C

# %%
##### Try the following commands and explain what is role of the * symbol
#! rm /content/genome/human/Homo_sapiens.GRCh38.114.chromosome.*.gz
! rm /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa.gz
! rm /content/genome/human/Homo_sapiens.GRCh38.114.chromosome.1.gff3.gz

# %% [markdown]
# ####  **Task03**:  Understand the difference between cat and less command, using /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa as an example?

# %%
! less /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa
! cat /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa

# %%
! head -5 /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa
# Out:
# >1 dna:chromosome chromosome:GRCh38:1:1:248956422:1 REF
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN

# %%
! head /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa
# Out:
# >1 dna:chromosome chromosome:GRCh38:1:1:248956422:1 REF
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN

# %%
! tail -5 /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa
# Out:
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN

# %%
! tail /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa
# Out:
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
# NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN

# %%
#### How to read the manual for a given command?
! man head
# Out:
# This system has been minimized by removing packages and content that are
# not required on a system that users do not log into.
#
# To restore this content, including manpages, you can run the 'unminimize'
# command. You will still need to ensure the 'man-db' package is installed.

# %%
# First, update your package list
# !sudo apt-get update

# Then, run unminimize. Use 'yes |' to automatically confirm prompts
# !yes | sudo /usr/local/sbin/unminimize

# Finally, ensure man-db is installed (it might be installed by unminimize, but it's good to be sure)
# !sudo apt-get install -y man-db
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [48.5 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,262 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,763 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,092 kB]
# ...

# %%
! man head
# Out:
# HEAD(1POSIX)               POSIX Programmer's Manual              HEAD(1POSIX)
#
# G
#        This  manual  page is part of the POSIX Programmer's Manual.  The Linux
#        implementation of this interface may differ (consult the  corresponding
#        Linux  manual page for details of Linux behavior), or the interface may
#        not be implemented on Linux.
#
# E
#        head — copy the first part of files
#
# S
# ]
#
# N
# d utility shall copy its input files  to  the  standard  output,
#        ending the output for each file at a designated point.
#
# n
# r shall be counted in units  of
#        lines.
#
# S
# d  utility  shall  conform  to  the  Base Definitions volume of
# s.
#
#        The following option shall be supported:
#
# r lines of each input file shall be copied  to
# r
#                  option-argument is a positive decimal integer.
#
# r lines,  it  shall  be  copied  to
#        standard output in its entirety. This shall not be an error.
#
# ...

# %%
#####
! cp /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa /content/genome/human/test.fa
! diff /content/genome/human/Homo_sapiens.GRCh38.dna.chromosome.1.fa /content/genome/human/test.fa

# %%
! head -10 /content/genome/human/test.fa > /content/genome/human/test1.fa
! tail -10 /content/genome/human/test.fa > /content/genome/human/test2.fa

# %%
! diff /content/genome/human/test1.fa /content/genome/human/test2.fa
# Out:
# 1d0
# < >1 dna:chromosome chromosome:GRCh38:1:1:248956422:1 REF
# 10a10
# > NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN

# %% [markdown]
# ##### **Attention**:  All the files downloaded and created using this notebook are temporary. If we turn off this notebook, they all disappeared.  What if we want to keep the downloaded files?

# %%
##### Connect to your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##### List the content of your google drive
! ls -al /content/drive/MyDrive
# Out:
# total 28
# drwx------ 2 root root 4096 Sep 14  2024  Colab_BIO466
# drwx------ 2 root root 4096 Apr  3 23:32  Colab_BIO485
# drwx------ 2 root root 4096 Mar  2 16:50  Colab_Lib
# drwx------ 2 root root 4096 Jan 14  2024 'Colab Notebooks'
# drwx------ 2 root root 4096 Jan 22  2024  Collaborator
# drwx------ 2 root root 4096 Sep 14  2024  Lab_share
# drwx------ 2 root root 4096 Jan 22  2024  Miami

# %%
##### Move the genome folder into your google drive
! mv /content/genome /content/drive/MyDrive/Colab_BIO466/

# %%
! ls -al /content/drive/MyDrive/Colab_BIO466/
# Out:
# total 16
# drwx------  2 root root 4096 Sep 14  2024 colab_env
# drwx------  2 root root 4096 Sep 14  2024 data
# drwx------+ 3 root root 4096 Jul  7 19:41 genome
# drwx------  2 root root 4096 Sep 15  2024 other_tools

# %%
! ls -al /content/drive/MyDrive/Colab_BIO466/genome/human
# Out:
# total 556577
# -rwx------+ 1 root root  63720222 Feb 15 15:49 Homo_sapiens.GRCh38.114.chromosome.1.gff3
# -rwx------+ 1 root root 253105752 Jan 30 20:44 Homo_sapiens.GRCh38.dna.chromosome.1.fa
# -rwx------+ 1 root root       605 Jul  7 19:30 test1.fa
# -rwx------+ 1 root root       592 Jul  7 19:30 test2.fa
# -rwx------+ 1 root root 253105752 Jul  7 19:29 test.fa
