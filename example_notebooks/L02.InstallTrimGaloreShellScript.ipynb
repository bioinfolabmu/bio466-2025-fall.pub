# %%
# @title ### **Step 1: Mount Google Drive & Install Tools**
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Follow the instruction https://github.com/FelixKrueger/TrimGalore
#
# Trim Galore is a a Perl wrapper around two tools: Cutadapt and FastQC. To use, ensure that these two pieces of software are available and copy the trim_galore script to a location available on the PATH

# %%
# 1. Install dependencies
# !pip install cutadapt
# !apt-get install perl

# 2. Download and install TrimGalore
# !wget https://github.com/FelixKrueger/TrimGalore/archive/refs/tags/0.6.10.tar.gz
# !tar -xzf 0.6.10.tar.gz

# 3. Make the script executable and add to PATH
import os
os.environ['PATH'] += os.pathsep + '/content/TrimGalore-0.6.10'

# 4. Verify installation
# !ls /content/TrimGalore-0.6.10/trim_galore  # Check if file exists
# !/content/TrimGalore-0.6.10/trim_galore --version
# Out:
# Requirement already satisfied: cutadapt in /usr/local/lib/python3.11/dist-packages (5.1)
# Requirement already satisfied: dnaio>=1.2.3 in /usr/local/lib/python3.11/dist-packages (from cutadapt) (1.2.3)
# Requirement already satisfied: xopen>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from cutadapt) (2.0.2)
# Requirement already satisfied: isal>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from xopen>=1.6.0->cutadapt) (1.7.2)
# Requirement already satisfied: zlib-ng>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from xopen>=1.6.0->cutadapt) (0.5.1)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# perl is already the newest version (5.34.0-3ubuntu1.4).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# --2025-07-15 20:21:34--  https://github.com/FelixKrueger/TrimGalore/archive/refs/tags/0.6.10.tar.gz
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/FelixKrueger/TrimGalore/tar.gz/refs/tags/0.6.10 [following]
# --2025-07-15 20:21:35--  https://codeload.github.com/FelixKrueger/TrimGalore/tar.gz/refs/tags/0.6.10
# Resolving codeload.github.com (codeload.github.com)... 140.82.116.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.116.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘0.6.10.tar.gz’
#
# 0.6.10.tar.gz           [     <=>            ]  25.59M  28.2MB/s    in 0.9s
#
# 2025-07-15 20:21:36 (28.2 MB/s) - ‘0.6.10.tar.gz’ saved [26831358]
#
# /content/TrimGalore-0.6.10/trim_galore
#
#                         Quality-/Adapter-/RRBS-/Speciality-Trimming
#                                 [powered by Cutadapt]
#                                   version 0.6.10
#
#                                Last update: 02 02 2023

# %%
! ls -al /content/drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/
# Out:
# total 4016603
# -rw------- 1 root root 348532629 Jul  9 01:13 YapPool_S01_sub_1.fq.gz
# -rw------- 1 root root 352131287 Jul  9 01:16 YapPool_S01_sub_2.fq.gz
# -rw------- 1 root root 355127133 Jul  9 01:29 YapPool_S02_sub_1.fq.gz
# -rw------- 1 root root 359222563 Jul  9 01:32 YapPool_S02_sub_2.fq.gz
# -rw------- 1 root root 304346742 Jul  9 01:45 YapPool_S03_sub_1.fq.gz
# -rw------- 1 root root 308548182 Jul  9 01:47 YapPool_S03_sub_2.fq.gz
# -rw------- 1 root root 364095003 Jul  9 01:59 YapPool_S09_sub_1.fq.gz
# -rw------- 1 root root 367720065 Jul  9 02:02 YapPool_S09_sub_2.fq.gz
# -rw------- 1 root root 345373866 Jul  9 02:16 YapPool_S10_sub_1.fq.gz
# -rw------- 1 root root 349413817 Jul  9 02:19 YapPool_S10_sub_2.fq.gz
# -rw------- 1 root root 327577645 Jul  9 02:31 YapPool_S11_sub_1.fq.gz
# -rw------- 1 root root 330909050 Jul  9 02:35 YapPool_S11_sub_2.fq.gz

# %%
##### This process is done within 5 minutes
# !trim_galore \
--paired \
--quality 20 \
--length 20 \
--gzip \
--output_dir ./ \
--fastqc \
--clip_R1 2 \
--clip_R2 2 \
--three_prime_clip_R1 2 \
--three_prime_clip_R2 2 \
--illumina \
drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_1.fq.gz \
drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_2.fq.gz
# Out:
# Multicore support not enabled. Proceeding with single-core trimming.
# Path to Cutadapt set as: 'cutadapt' (default)
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt version: 5.1
# single-core operation.
# Proceeding with 'gzip' for decompression
# To decrease CPU usage of decompression, please install 'igzip' and run again
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Output will be written into the directory: /content/
# Writing report to '/content/YapPool_S01_sub_1.fq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_1.fq.gz
# Trimming mode: paired-end
# Trim Galore version: 0.6.10
# Cutadapt version: 5.1
# Number of cores used for trimming: 1
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; user defined)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length for both reads before a sequence pair gets removed: 20 bp
# All Read 1 sequences will be trimmed by 2 bp from their 5' end to avoid poor qualities or biases
# All Read 2 sequences will be trimmed by 2 bp from their 5' end to avoid poor qualities or biases (e.g. M-bias for BS-Seq applications)
# All Read 1 sequences will be trimmed by 2 bp from their 3' end to avoid poor qualities or biases
# All Read 2 sequences will be trimmed by 2 bp from their 3' end to avoid poor qualities or biases
# Running FastQC on the data once trimming has completed
# Output file(s) will be GZIP compressed
#
# Cutadapt seems to be fairly up-to-date (version 5.1). Setting -j 1
# Writing final adapter and quality trimmed output to YapPool_S01_sub_1_trimmed.fq.gz
#
#
#   >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_1.fq.gz <<<
# This is cutadapt 5.1 with Python 3.11.13
# Command line parameters: -j 1 -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_1.fq.gz
# Processing single-end reads on 1 core ...
#
# === Summary ===
#
# Total reads processed:               5,605,279
# Reads with adapters:                 2,679,013 (47.8%)
# Reads written (passing filters):     5,605,279 (100.0%)
#
# Total basepairs processed:   840,791,850 bp
# Quality-trimmed:               7,361,624 bp (0.9%)
# Total written (filtered):    794,723,499 bp (94.5%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 2679013 times
#
# Minimum overlap: 1
# No. of allowed errors:
# 1-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
#   A: 22.1%
#   C: 32.1%
#   G: 27.6%
#   T: 16.4%
#   none/other: 1.8%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	999472	1401319.8	0	999472
# 2	332683	350329.9	0	332683
# 3	111070	87582.5	0	111070
# 4	49003	21895.6	0	49003
# 5	36814	5473.9	0	36814
# 6	32356	1368.5	0	32356
# 7	32074	342.1	0	32074
# 8	31044	85.5	0	31044
# 9	31651	21.4	0	31512 139
# 10	31034	5.3	1	30648 386
# 11	31528	1.3	1	31095 433
# 12	30166	0.3	1	29754 412
# 13	30504	0.1	1	30037 467
# 14	29963	0.1	1	29576 387
# 15	29905	0.1	1	29431 474
# 16	29237	0.1	1	28796 441
# 17	29686	0.1	1	29200 486
# 18	27821	0.1	1	27429 392
# 19	28101	0.1	1	27716 385
# 20	27086	0.1	1	26683 403
# 21	27464	0.1	1	26985 479
# 22	26463	0.1	1	26099 364
# 23	25823	0.1	1	25450 373
# 24	25209	0.1	1	24857 352
# 25	24819	0.1	1	24438 381
# 26	24423	0.1	1	24087 336
# 27	23821	0.1	1	23467 354
# 28	23401	0.1	1	23050 351
# 29	22643	0.1	1	22309 334
# 30	21536	0.1	1	21233 303
# 31	21363	0.1	1	21047 316
# 32	21274	0.1	1	20933 341
# 33	19752	0.1	1	19451 301
# 34	19521	0.1	1	19221 300
# 35	18590	0.1	1	18303 287
# 36	17837	0.1	1	17573 264
# 37	17644	0.1	1	17312 332
# 38	17203	0.1	1	16920 283
# 39	15575	0.1	1	15306 269
# 40	15431	0.1	1	15106 325
# 41	16013	0.1	1	15497 516
# 42	17051	0.1	1	16602 449
# 43	13487	0.1	1	13202 285
# 44	13083	0.1	1	12865 218
# 45	10716	0.1	1	10437 279
# 46	12055	0.1	1	11750 305
# 47	12852	0.1	1	12479 373
# 48	14403	0.1	1	14054 349
# 49	14919	0.1	1	14456 463
# 50	28659	0.1	1	28232 427
# 51	25918	0.1	1	25637 281
# 52	12709	0.1	1	12485 224
# 53	12399	0.1	1	12258 141
# 54	8774	0.1	1	8695 79
# 55	2375	0.1	1	2335 40
# 56	882	0.1	1	861 21
# 57	474	0.1	1	467 7
# 58	227	0.1	1	220 7
# 59	164	0.1	1	160 4
# 60	65	0.1	1	58 7
# 61	53	0.1	1	42 11
# 62	28	0.1	1	22 6
# 63	14	0.1	1	7 7
# 64	11	0.1	1	6 5
# 65	11	0.1	1	7 4
# 66	17	0.1	1	7 10
# 67	17	0.1	1	11 6
# 68	28	0.1	1	16 12
# 69	35	0.1	1	7 28
# 70	15	0.1	1	5 10
# 71	15	0.1	1	4 11
# 72	15	0.1	1	8 7
# 73	11	0.1	1	7 4
# 74	19	0.1	1	9 10
# 75	20	0.1	1	12 8
# 76	14	0.1	1	7 7
# 77	30	0.1	1	19 11
# 78	26	0.1	1	20 6
# 79	26	0.1	1	25 1
# 80	23	0.1	1	17 6
# 81	35	0.1	1	25 10
# 82	29	0.1	1	25 4
# 83	36	0.1	1	29 7
# 84	28	0.1	1	24 4
# 85	31	0.1	1	27 4
# 86	30	0.1	1	25 5
# 87	26	0.1	1	21 5
# 88	34	0.1	1	24 10
# 89	35	0.1	1	21 14
# 90	37	0.1	1	35 2
# 91	44	0.1	1	36 8
# 92	28	0.1	1	26 2
# 93	38	0.1	1	33 5
# 94	29	0.1	1	28 1
# 95	49	0.1	1	42 7
# 96	33	0.1	1	31 2
# 97	61	0.1	1	52 9
# 98	69	0.1	1	51 18
# 99	90	0.1	1	75 15
# 100	53	0.1	1	47 6
# 101	59	0.1	1	53 6
# 102	61	0.1	1	53 8
# 103	53	0.1	1	46 7
# 104	39	0.1	1	37 2
# 105	48	0.1	1	42 6
# 106	55	0.1	1	46 9
# 107	28	0.1	1	26 2
# 108	41	0.1	1	36 5
# 109	46	0.1	1	41 5
# 110	32	0.1	1	27 5
# 111	36	0.1	1	32 4
# 112	29	0.1	1	25 4
# 113	31	0.1	1	28 3
# 114	37	0.1	1	31 6
# 115	39	0.1	1	33 6
# 116	36	0.1	1	28 8
# 117	39	0.1	1	35 4
# 118	51	0.1	1	44 7
# 119	33	0.1	1	25 8
# 120	39	0.1	1	23 16
# 121	43	0.1	1	30 13
# 122	38	0.1	1	30 8
# 123	43	0.1	1	29 14
# 124	28	0.1	1	19 9
# 125	27	0.1	1	20 7
# 126	55	0.1	1	39 16
# 127	43	0.1	1	34 9
# 128	43	0.1	1	33 10
# 129	60	0.1	1	40 20
# 130	51	0.1	1	42 9
# 131	63	0.1	1	55 8
# 132	58	0.1	1	44 14
# 133	67	0.1	1	58 9
# 134	75	0.1	1	63 12
# 135	70	0.1	1	56 14
# 136	101	0.1	1	85 16
# 137	87	0.1	1	79 8
# 138	96	0.1	1	81 15
# 139	68	0.1	1	64 4
# 140	105	0.1	1	99 6
# 141	188	0.1	1	176 12
# 142	88	0.1	1	80 8
# 143	105	0.1	1	100 5
# 144	164	0.1	1	148 16
# 145	191	0.1	1	168 23
# 146	223	0.1	1	202 21
# 147	390	0.1	1	363 27
# 148	169	0.1	1	107 62
# 149	543	0.1	1	5 538
# 150	45441	0.1	1	82 45359
#
# RUN STATISTICS FOR INPUT FILE: drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_1.fq.gz
# =============================================
# 5605279 sequences processed in total
# The length threshold of paired-end sequences gets evaluated later on (in the validation step)
#
# Writing report to '/content/YapPool_S01_sub_2.fq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_2.fq.gz
# Trimming mode: paired-end
# Trim Galore version: 0.6.10
# Cutadapt version: 5.1
# Number of cores used for trimming: 1
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; user defined)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length for both reads before a sequence pair gets removed: 20 bp
# All Read 1 sequences will be trimmed by 2 bp from their 5' end to avoid poor qualities or biases
# All Read 2 sequences will be trimmed by 2 bp from their 5' end to avoid poor qualities or biases (e.g. M-bias for BS-Seq applications)
# All Read 1 sequences will be trimmed by 2 bp from their 3' end to avoid poor qualities or biases
# All Read 2 sequences will be trimmed by 2 bp from their 3' end to avoid poor qualities or biases
# Running FastQC on the data once trimming has completed
# Output file(s) will be GZIP compressed
#
# Cutadapt seems to be fairly up-to-date (version 5.1). Setting -j -j 1
# Writing final adapter and quality trimmed output to YapPool_S01_sub_2_trimmed.fq.gz
#
#
#   >>> Now performing quality (cutoff '-q 20') and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_2.fq.gz <<<
# This is cutadapt 5.1 with Python 3.11.13
# Command line parameters: -j 1 -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_2.fq.gz
# Processing single-end reads on 1 core ...
#
# === Summary ===
#
# Total reads processed:               5,605,279
# Reads with adapters:                 2,723,985 (48.6%)
# Reads written (passing filters):     5,605,279 (100.0%)
#
# Total basepairs processed:   840,791,850 bp
# Quality-trimmed:              10,783,043 bp (1.3%)
# Total written (filtered):    798,166,168 bp (94.9%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 2723985 times
#
# Minimum overlap: 1
# No. of allowed errors:
# 1-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
#   A: 24.7%
#   C: 30.1%
#   G: 32.3%
#   T: 13.0%
#   none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	1056283	1401319.8	0	1056283
# 2	346103	350329.9	0	346103
# 3	132272	87582.5	0	132272
# 4	53052	21895.6	0	53052
# 5	37439	5473.9	0	37439
# 6	32941	1368.5	0	32941
# 7	32220	342.1	0	32220
# 8	31357	85.5	0	31357
# 9	31571	21.4	0	31441 130
# 10	31466	5.3	1	31045 421
# 11	31762	1.3	1	31299 463
# 12	31370	0.3	1	30931 439
# 13	29866	0.1	1	29536 330
# 14	30529	0.1	1	30130 399
# 15	30209	0.1	1	29795 414
# 16	29186	0.1	1	28815 371
# 17	29900	0.1	1	29468 432
# 18	29188	0.1	1	28714 474
# 19	34772	0.1	1	34038 734
# 20	28479	0.1	1	28111 368
# 21	24874	0.1	1	24656 218
# 22	24277	0.1	1	24078 199
# 23	25537	0.1	1	25283 254
# 24	30468	0.1	1	30132 336
# 25	21064	0.1	1	20870 194
# 26	25188	0.1	1	24967 221
# 27	32895	0.1	1	32597 298
# 28	18756	0.1	1	18519 237
# 29	27924	0.1	1	27691 233
# 30	19247	0.1	1	19034 213
# 31	21867	0.1	1	21679 188
# 32	17552	0.1	1	17398 154
# 33	34142	0.1	1	33941 201
# 34	12576	0.1	1	12436 140
# 35	14585	0.1	1	14438 147
# 36	24861	0.1	1	24732 129
# 37	13322	0.1	1	13205 117
# 38	17840	0.1	1	17734 106
# 39	12517	0.1	1	12417 100
# 40	25779	0.1	1	25679 100
# 41	5472	0.1	1	5389 83
# 42	13006	0.1	1	12931 75
# 43	16348	0.1	1	16265 83
# 44	8163	0.1	1	8091 72
# 45	14613	0.1	1	14530 83
# 46	19204	0.1	1	19117 87
# 47	9029	0.1	1	8948 81
# 48	9365	0.1	1	9320 45
# 49	6292	0.1	1	6233 59
# 50	11794	0.1	1	11751 43
# 51	3003	0.1	1	2959 44
# 52	9419	0.1	1	9375 44
# 53	4913	0.1	1	4875 38
# 54	4662	0.1	1	4626 36
# 55	7290	0.1	1	7251 39
# 56	3230	0.1	1	3196 34
# 57	2047	0.1	1	2024 23
# 58	5080	0.1	1	5052 28
# 59	819	0.1	1	803 16
# 60	2304	0.1	1	2287 17
# 61	2518	0.1	1	2497 21
# 62	3160	0.1	1	3137 23
# 63	3568	0.1	1	3551 17
# 64	342	0.1	1	331 11
# 65	895	0.1	1	873 22
# 66	878	0.1	1	860 18
# 67	1273	0.1	1	1251 22
# 68	1152	0.1	1	1131 21
# 69	1071	0.1	1	1053 18
# 70	1024	0.1	1	1020 4
# 71	866	0.1	1	855 11
# 72	989	0.1	1	980 9
# 73	895	0.1	1	886 9
# 74	797	0.1	1	785 12
# 75	811	0.1	1	800 11
# 76	744	0.1	1	729 15
# 77	762	0.1	1	752 10
# 78	669	0.1	1	662 7
# 79	624	0.1	1	617 7
# 80	527	0.1	1	522 5
# 81	524	0.1	1	515 9
# 82	454	0.1	1	442 12
# 83	429	0.1	1	410 19
# 84	392	0.1	1	379 13
# 85	368	0.1	1	357 11
# 86	372	0.1	1	359 13
# 87	319	0.1	1	305 14
# 88	273	0.1	1	263 10
# 89	288	0.1	1	283 5
# 90	269	0.1	1	260 9
# 91	245	0.1	1	229 16
# 92	183	0.1	1	181 2
# 93	187	0.1	1	182 5
# 94	143	0.1	1	137 6
# 95	139	0.1	1	135 4
# 96	104	0.1	1	100 4
# 97	144	0.1	1	137 7
# 98	109	0.1	1	104 5
# 99	123	0.1	1	116 7
# 100	99	0.1	1	94 5
# 101	91	0.1	1	85 6
# 102	91	0.1	1	79 12
# 103	68	0.1	1	62 6
# 104	54	0.1	1	48 6
# 105	61	0.1	1	55 6
# 106	66	0.1	1	54 12
# 107	45	0.1	1	34 11
# 108	56	0.1	1	45 11
# 109	72	0.1	1	50 22
# 110	40	0.1	1	38 2
# 111	40	0.1	1	38 2
# 112	43	0.1	1	34 9
# 113	40	0.1	1	33 7
# 114	42	0.1	1	33 9
# 115	45	0.1	1	36 9
# 116	34	0.1	1	30 4
# 117	41	0.1	1	35 6
# 118	52	0.1	1	44 8
# 119	40	0.1	1	30 10
# 120	35	0.1	1	26 9
# 121	56	0.1	1	30 26
# 122	37	0.1	1	31 6
# 123	39	0.1	1	31 8
# 124	33	0.1	1	26 7
# 125	47	0.1	1	28 19
# 126	46	0.1	1	43 3
# 127	42	0.1	1	36 6
# 128	43	0.1	1	32 11
# 129	74	0.1	1	46 28
# 130	54	0.1	1	43 11
# 131	66	0.1	1	57 9
# 132	55	0.1	1	45 10
# 133	68	0.1	1	60 8
# 134	68	0.1	1	65 3
# 135	77	0.1	1	57 20
# 136	101	0.1	1	89 12
# 137	96	0.1	1	84 12
# 138	99	0.1	1	94 5
# 139	82	0.1	1	70 12
# 140	112	0.1	1	103 9
# 141	198	0.1	1	185 13
# 142	86	0.1	1	84 2
# 143	110	0.1	1	104 6
# 144	161	0.1	1	154 7
# 145	188	0.1	1	181 7
# 146	214	0.1	1	208 6
# 147	392	0.1	1	369 23
# 148	120	0.1	1	110 10
# 149	11	0.1	1	5 6
# 150	136	0.1	1	85 51
#
# RUN STATISTICS FOR INPUT FILE: drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq/YapPool_S01_sub_2.fq.gz
# =============================================
# 5605279 sequences processed in total
# The length threshold of paired-end sequences gets evaluated later on (in the validation step)
#
# Validate paired-end files YapPool_S01_sub_1_trimmed.fq.gz and YapPool_S01_sub_2_trimmed.fq.gz
# file_1: YapPool_S01_sub_1_trimmed.fq.gz, file_2: YapPool_S01_sub_2_trimmed.fq.gz
#
#
# >>>>> Now validing the length of the 2 paired-end infiles: YapPool_S01_sub_1_trimmed.fq.gz and YapPool_S01_sub_2_trimmed.fq.gz <<<<<
# Writing validated paired-end Read 1 reads to YapPool_S01_sub_1_val_1.fq.gz
# Writing validated paired-end Read 2 reads to YapPool_S01_sub_2_val_2.fq.gz
#
# Total number of sequences analysed: 5605279
#
# Number of sequence pairs removed because at least one read was shorter than the length cutoff (20 bp): 75357 (1.34%)
#
#
#   >>> Now running FastQC on the validated data YapPool_S01_sub_1_val_1.fq.gz<<<
#
# Can't exec "fastqc": No such file or directory at /content/TrimGalore-0.6.10/trim_galore line 1555, <IN2> line 22421116.
#
#   >>> Now running FastQC on the validated data YapPool_S01_sub_2_val_2.fq.gz<<<
#
# Can't exec "fastqc": No such file or directory at /content/TrimGalore-0.6.10/trim_galore line 1565, <IN2> line 22421116.
# Deleting both intermediate output files YapPool_S01_sub_1_trimmed.fq.gz and YapPool_S01_sub_2_trimmed.fq.gz
#
# ====================================================================================================

# %%
# %%writefile run_trimgalore.sh
# #!/bin/bash
#
# # Exit immediately if a command exits with a non-zero status.
# set -e
#
# echo "Starting TrimGalore process..."
#
# # --- Configuration for inputs and outputs ---
# SEQ_DIR='drive/MyDrive/Lab_share/Lab_data/class_466/raw.small.RNA-Seq'
# OUT_DIR='drive/MyDrive/Lab_share/Lab_data/class_466/clean.trimgalore.RNA-Seq'
# # Define samples as a bash array
# SAMPLES=("YapPool_S01" "YapPool_S02" "YapPool_S03" "YapPool_S09" "YapPool_S10" "YapPool_S11")
#
# # Create the output directory if it doesn't exist
# mkdir -p ${OUT_DIR}
# echo "Ensured output directory exists: ${OUT_DIR}"
#
# # Loop through each sample and run TrimGalore
# for SAMPLE in "${SAMPLES[@]}"; do
#     echo "Processing sample: ${SAMPLE}"
#
#     trim_galore \
#     --paired \
#     --quality 20 \
#     --length 20 \
#     --gzip \
#     --output_dir ${OUT_DIR} \
#     --clip_R1 2 \
#     --clip_R2 2 \
#     --three_prime_clip_R1 2 \
#     --three_prime_clip_R2 2 \
#     --illumina \
#     --basename ${SAMPLE}_trim_ \
#     ${SEQ_DIR}/${SAMPLE}_sub_1.fq.gz \
#     ${SEQ_DIR}/${SAMPLE}_sub_2.fq.gz \
#     > ${OUT_DIR}/${SAMPLE}_trim.log 2>&1
#
#     echo "Finished processing ${SAMPLE}"
# done
# Out:
# Writing run_trimgalore.sh

# %%
! chmod +x run_trimgalore.sh

# %%
# This took 140 minutes to finish
! time ./run_trimgalore.sh
# Out:
# /bin/bash: line 1: ./run_trimgalore.sh: No such file or directory
#
# real	0m0.002s
# user	0m0.001s
# sys	0m0.001s

# %%
! ls -al drive/MyDrive/Lab_share/Lab_data/class_466/clean.trimgalore.RNA-Seq/
# Out:
# total 3761363
# -rw------- 1 root root      5244 Jul 15 20:55 YapPool_S01_sub_1.fq.gz_trimming_report.txt
# -rw------- 1 root root      5540 Jul 15 21:07 YapPool_S01_sub_2.fq.gz_trimming_report.txt
# -rw------- 1 root root     13637 Jul 15 21:08 YapPool_S01_trim.log
# -rw------- 1 root root 327476943 Jul 15 21:00 YapPool_S01_trim__val_1.fq.gz
# -rw------- 1 root root 328406041 Jul 15 21:00 YapPool_S01_trim__val_2.fq.gz
# -rw------- 1 root root      5251 Jul 15 21:13 YapPool_S02_sub_1.fq.gz_trimming_report.txt
# -rw------- 1 root root      5535 Jul 15 21:25 YapPool_S02_sub_2.fq.gz_trimming_report.txt
# -rw------- 1 root root     13639 Jul 15 21:25 YapPool_S02_trim.log
# -rw------- 1 root root 334036068 Jul 15 21:18 YapPool_S02_trim__val_1.fq.gz
# -rw------- 1 root root 334476109 Jul 15 21:18 YapPool_S02_trim__val_2.fq.gz
# -rw------- 1 root root      5135 Jul 15 21:30 YapPool_S03_sub_1.fq.gz_trimming_report.txt
# -rw------- 1 root root      5516 Jul 15 21:41 YapPool_S03_sub_2.fq.gz_trimming_report.txt
# -rw------- 1 root root     13504 Jul 15 21:41 YapPool_S03_trim.log
# -rw------- 1 root root 286745659 Jul 15 21:34 YapPool_S03_trim__val_1.fq.gz
# -rw------- 1 root root 287838243 Jul 15 21:34 YapPool_S03_trim__val_2.fq.gz
# -rw------- 1 root root      5179 Jul 15 21:46 YapPool_S09_sub_1.fq.gz_trimming_report.txt
# -rw------- 1 root root      5530 Jul 15 21:59 YapPool_S09_sub_2.fq.gz_trimming_report.txt
# -rw------- 1 root root     13562 Jul 15 21:59 YapPool_S09_trim.log
# -rw------- 1 root root 341248598 Jul 15 21:51 YapPool_S09_trim__val_1.fq.gz
# -rw------- 1 root root 341412534 Jul 15 21:51 YapPool_S09_trim__val_2.fq.gz
# -rw------- 1 root root      5134 Jul 15 22:04 YapPool_S10_sub_1.fq.gz_trimming_report.txt
# -rw------- 1 root root      5517 Jul 15 22:16 YapPool_S10_sub_2.fq.gz_trimming_report.txt
# -rw------- 1 root root     13504 Jul 15 22:16 YapPool_S10_trim.log
# -rw------- 1 root root 325975987 Jul 15 22:09 YapPool_S10_trim__val_1.fq.gz
# -rw------- 1 root root 326857371 Jul 15 22:09 YapPool_S10_trim__val_2.fq.gz
# -rw------- 1 root root      5146 Jul 15 22:21 YapPool_S11_sub_1.fq.gz_trimming_report.txt
# -rw------- 1 root root      5510 Jul 15 22:32 YapPool_S11_sub_2.fq.gz_trimming_report.txt
# -rw------- 1 root root     13509 Jul 15 22:33 YapPool_S11_trim.log
# -rw------- 1 root root 308137243 Jul 15 22:25 YapPool_S11_trim__val_1.fq.gz
# -rw------- 1 root root 308870036 Jul 15 22:25 YapPool_S11_trim__val_2.fq.gz

# %%
! pip install multiqc
# Out:
# Collecting multiqc
#   Downloading multiqc-1.30-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 2.1 MB/s eta 0:00:00
# Collecting boto3 (from multiqc)
#   Downloading boto3-1.39.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from multiqc) (8.2.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from multiqc) (4.12.3)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from multiqc) (8.7.0)
# Requirement already satisfied: jinja2>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from multiqc) (3.1.6)
# Collecting kaleido==0.2.1 (from multiqc)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from multiqc) (3.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from multiqc) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from multiqc) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from multiqc) (2.32.3)
# Requirement already satisfied: Pillow>=10 in /usr/local/lib/python3.11/dist-packages (from multiqc) (11.2.1)
# Requirement already satisfied: plotly>=5.18 in /usr/local/lib/python3.11/dist-packages (from multiqc) (5.24.1)
# Requirement already satisfied: pyyaml>=4 in /usr/local/lib/python3.11/dist-packages (from multiqc) (6.0.2)
# Requirement already satisfied: rich>=10 in /usr/local/lib/python3.11/dist-packages (from multiqc) (13.9.4)
# Collecting rich-click (from multiqc)
#   Downloading rich_click-1.8.9-py3-none-any.whl.metadata (7.9 kB)
# Collecting coloredlogs (from multiqc)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting spectra>=0.0.10 (from multiqc)
#   Downloading spectra-0.1.0-py3-none-any.whl.metadata (927 bytes)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from multiqc) (2.11.7)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.11/dist-packages (from multiqc) (4.4.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from multiqc) (4.67.1)
# Collecting python-dotenv (from multiqc)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from multiqc) (8.4.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from multiqc) (0.9.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from multiqc) (4.24.0)
# Collecting polars-lts-cpu (from multiqc)
#   Downloading polars_lts_cpu-1.31.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from multiqc) (18.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.0.0->multiqc) (3.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.18->multiqc) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->multiqc) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->multiqc) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->multiqc) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->multiqc) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10->multiqc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10->multiqc) (2.19.2)
# Collecting colormath2>=3.0.0 (from spectra>=0.0.10->multiqc)
#   Downloading colormath2-3.0.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting botocore<1.40.0,>=1.39.5 (from boto3->multiqc)
#   Downloading botocore-1.39.5-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->multiqc)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3->multiqc)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->multiqc)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->multiqc) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->multiqc) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->multiqc) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->multiqc) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->multiqc) (0.26.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->multiqc) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->multiqc) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->multiqc) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->multiqc) (2025.7.9)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->multiqc) (2024.11.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.40.0,>=1.39.5->boto3->multiqc) (2.9.0.post0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.11/dist-packages (from colormath2>=3.0.0->spectra>=0.0.10->multiqc) (3.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10->multiqc) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.40.0,>=1.39.5->boto3->multiqc) (1.17.0)
# Downloading multiqc-1.30-py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 43.8 MB/s eta 0:00:00
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.2 MB/s eta 0:00:00
# Downloading spectra-0.1.0-py3-none-any.whl (17 kB)
# Downloading boto3-1.39.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 8.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.8 MB/s eta 0:00:00
# Downloading polars_lts_cpu-1.31.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.7/34.7 MB 36.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading rich_click-1.8.9-py3-none-any.whl (36 kB)
# Downloading botocore-1.39.5-py3-none-any.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 81.2 MB/s eta 0:00:00
# Downloading colormath2-3.0.3-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: kaleido, python-dotenv, polars-lts-cpu, jmespath, humanfriendly, colormath2, spectra, coloredlogs, botocore, s3transfer, rich-click, boto3, multiqc
# Successfully installed boto3-1.39.5 botocore-1.39.5 coloredlogs-15.0.1 colormath2-3.0.3 humanfriendly-10.0 jmespath-1.0.1 kaleido-0.2.1 multiqc-1.30 polars-lts-cpu-1.31.0 python-dotenv-1.1.1 rich-click-1.8.9 s3transfer-0.13.0 spectra-0.1.0

# %%
# !multiqc drive/MyDrive/Lab_share/Lab_data/class_466/clean.trimgalore.RNA-Seq/
# Out:
# /// ]8;id=11701;https://multiqc.info\MultiQC]8;;\ 🔍 v1.30
#
#        file_search | Search path: /content/drive/MyDrive/Lab_share/Lab_data/class_466/clean.trimgalore.RNA-Seq
#          searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 30/30
#           cutadapt | Found 12 reports
#      write_results | Data        : multiqc_data
#      write_results | Report      : multiqc_report.html
#            multiqc | MultiQC complete

# %%
! ls -al
# Out:
# total 4752
# drwxr-xr-x 1 root root    4096 Jul 16 01:30 .
# drwxr-xr-x 1 root root    4096 Jul 15 23:38 ..
# drwxr-xr-x 4 root root    4096 Jul 14 13:37 .config
# drwx------ 5 root root    4096 Jul 15 23:40 drive
# drwxr-xr-x 2 root root    4096 Jul 16 01:30 multiqc_data
# -rw-r--r-- 1 root root 4839639 Jul 16 01:30 multiqc_report.html
# drwxr-xr-x 1 root root    4096 Jul 14 13:37 sample_data

# %%
from IPython.display import HTML
import os

html_file_name = '/content/multiqc_report.html' # Replace with your HTML file
html_file_path = os.path.join(os.getcwd(), html_file_name)

if not os.path.exists(html_file_path):
    print(f"Error: {html_file_path} not found.")
else:
    with open(html_file_path, 'r', encoding='utf-8') as f:
        html_content = f.read()

    display(HTML(html_content))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
